# %%
import pymongo
import pandas as pd
conn = pymongo.Connection("mongodb://asi-fellow:asi@c402.lamppost.3.mongolayer.com:10402,c520.lamppost.6.mongolayer.com:10520/asi?replicaSet=set-54eb0df990439c3a94000fd5")
print type(conn)
# Out:
# <class 'pymongo.connection.Connection'>

# %%
db = conn['asi']
print db
db.collection_names()
businesses = db['business']
users = db['user']
checkins = db['checkin']
tips = db['tip']
reviews = db['review']
# Out:
# Database(Connection([u'c402.lamppost.3.mongolayer.com:10402', u'c520.lamppost.6.mongolayer.com:10520']), u'asi')

# %%
def read_mongo(collection, query={}, limit=3):
    """ Read from Mongo and Store into DataFrame """
    # Collection
    cursor = collection.find(query).limit(limit)

    # Expand the cursor and construct the DataFrame
    df =  pd.DataFrame(list(cursor))

    return df
#read_mongo(businesses, {'stars':5,'review_count':{'$gt': 50}}, 3)
#read_mongo(users, {}, 3)
#read_mongo(checkins, {}, 3)
#read_mongo(tips, {},3)
#read_mongo(reviews, {},3)

# %%
#len(businesses.distinct('categories'))
#businesses.distinct('categories').limit(200)
#len(users.distinct('compliments'))
#users.distinct('compliments').limit(200)
#len(reviews.distinct('votes'))
#reviews.distinct('votes').limit(200)

# %%
list_cat = []
list_val = []
cursor = businesses.find({})
df =  pd.DataFrame(list(cursor))
df.categories.value_counts()
# Out:
# [Mexican, Restaurants]                                  1481
# [Pizza, Restaurants]                                    1068
# [Hotels & Travel, Event Planning & Services, Hotels]     982
# [Food, Coffee & Tea]                                     958
# [Chinese, Restaurants]                                   934
# [Beauty & Spas, Nail Salons]                             883
# [Restaurants, Italian]                                   674
# [Hair Salons, Beauty & Spas]                             651
# [Food, Grocery]                                          585
# [Burgers, Fast Food, Restaurants]                        582
# [American (Traditional), Restaurants]                    535
# []                                                       517
# [Food, Ice Cream & Frozen Yogurt]                        514
# [Fast Food, Restaurants]                                 507
# [American (New), Restaurants]                            495
# ...
# ...

# %% [markdown]
# Get dataframe with all business that have category 'Restaurants'

# %%
df_id =  pd.DataFrame(list(businesses.find({'categories':'Restaurants'},{'business_id':1,'_id':0})))
id_list = []
for i in df_id.business_id:
    id_list.append(i)
len(id_list)
# Out:
# 21892

# %% [markdown]
# Get all the reviews from the specified business_ids, include only the review text and the votes

# %%
df =  pd.DataFrame(list(reviews.find({"business_id": {'$in': id_list}},{'votes':1,'text':1,'stars':1,'_id':0}).limit(15000)))

# %% [markdown]
# Split up the votes dictionary into useful, funny and cool; add a column for each value to the data frame

# %%
list1 = []
list2 = []
list3 = []
for i in df.votes:
    list1.append(i['useful'])
    list2.append(i['funny'])
    list3.append(i['cool'])
df['useful'] = pd.Series(list1, index=df.index)
df['funny'] = pd.Series(list2, index=df.index)
df['cool'] = pd.Series(list3, index=df.index)

# %%
df.head()
# Out:
#    stars                                               text  \
# 0      5  Great guys, great food. Plus right next to one...
# 1      5  This location has been many different restaura...
# 2      5  WOW. I am sitting here with a full belly, abso...
# 3      5  This neighborhood niche is one of my favorite ...
# 4      4  This place has great salads! Right next to Sky...
#
#                                      votes  useful  funny  cool
# 0  {u'funny': 1, u'useful': 1, u'cool': 1}       1      1     1
# 1  {u'funny': 2, u'useful': 2, u'cool': 2}       2      2     2
# 2  {u'funny': 1, u'useful': 2, u'cool': 1}       2      1     1
# 3  {u'funny': 0, u'useful': 0, u'cool': 1}       0      0     1
# 4  {u'funny': 0, u'useful': 0, u'cool': 0}       0      0     0

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import pylab
#import scipy.statsmodels as stats
mpl.style.available
mpl.style.use('ggplot') 
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-b8429613c0e1> in <module>()
#       5 import pylab
#       6 #import scipy.statsmodels as stats
# ----> 7 mpl.style.available
#       8 mpl.style.use('ggplot')
#       9 get_ipython().magic(u'matplotlib inline')
#
# AttributeError: 'module' object has no attribute 'style'

# %%
pd.scatter_matrix(df);

# %% [markdown]
# Count the number of words in text

# %%
list4 = []
for i in df.text:
    list4.append(len(i.split()))

df['word_nr'] = pd.Series(list4, index=df.index)

# %% [markdown]
# Tokenize the text for each review

# %%
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

stopset = set(stopwords.words('english'))
tokenizer = RegexpTokenizer(r'\w+')

list5=[]
for each in df.text:
    tokens = tokenizer.tokenize(each)
    doc = [word for word in tokens if word not in stopset and len(word) > 3]
    list5.append(doc)
words_list=[]
for wlist in list5:
    words=[]
    for word in wlist:
        words.append(word.lower())
    words_list.append(words)
df['word_list'] = pd.Series(words_list, index=df.index)
#df

# %%
list6 = []
for i in df.word_list:
    list6.append(len(i))

df['word_nr_rel'] = pd.Series(list6, index=df.index)
df['ratio_noStop']=df.word_nr_rel/df.word_nr
#pd.scatter_matrix(df);

# %%
df_sorted=df.sort('useful',ascending=False)
df_50=df_sorted[:50]
df_50=df_50[['useful','funny','cool','word_nr','word_list','word_nr_rel']]
#df_50

# %%
type_list=[]
for wlist in df.word_list:
    type_list.append(nltk.pos_tag(wlist))
df['word_list_type']= pd.Series(type_list, index=df.index)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-20-686d5d424526> in <module>()
#       1 type_list=[]
#       2 for wlist in df.word_list:
# ----> 3     type_list.append(nltk.pos_tag(wlist))
#       4 df['word_list_type']= pd.Series(type_list, index=df.index)
#
# /usr/local/lib/python2.7/dist-packages/nltk/tag/__init__.pyc in pos_tag(tokens)
#      98     :rtype: list(tuple(str, str))
#      99     """
# --> 100     tagger = load(_POS_TAGGER)
#     101     return tagger.tag(tokens)
#     102
#
# /usr/local/lib/python2.7/dist-packages/nltk/data.pyc in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     772
#     773     # Load the resource.
# --> 774     opened_resource = _open(resource_url)
#     775
#     776     if format == 'raw':
#
# /usr/local/lib/python2.7/dist-packages/nltk/data.pyc in _open(resource_url)
#     886
# ...

# %%
#df = df.drop('votes', 1)
#df = df.drop('text', 1)

# %%
df['word_list_type'][1][1][1]
list1=[]
list2=[]
list3=[]
for each in df['word_list_type']:
    for every in each:
        list1.append(every[1])
    list2.append(list1)
df['word_type'] = pd.Series(list2, index=df.index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-7af389aa6a99> in <module>()
# ----> 1 df['word_list_type'][1][1][1]
#       2 list1=[]
#       3 list2=[]
#       4 list3=[]
#       5 for each in df['word_list_type']:
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1676             return self._getitem_multilevel(key)
#    1677         else:
# -> 1678             return self._getitem_column(key)
#    1679
#    1680     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1683         # get column
#    1684         if self.columns.is_unique:
# -> 1685             return self._get_item_cache(key)
#    1686
#    1687         # duplicate columns & possible reduce dimensionaility
#
# ...

# %%
from nltk.corpus import sentiwordnet as swn
pos_list=[]
neg_list=[]
obj_list=[]
index = 0
for wlist in df.word_list:
    pos=[]
    neg=[]
    obj=[]
    index2=0
    for word in wlist:
        #if df.word_type[index][index2]=='JJ':
        doc = list(swn.senti_synsets(word))
        try:
            doc0=list(doc)[0]
            pos.append(doc0.pos_score())
            neg.append(doc0.neg_score())
            obj.append(doc0.obj_score())
        except IndexError:       
            pos.append(0)
            neg.append(0)
            obj.append(0)
        index2=index2+1
    pos_list.append(sum(pos)/len(pos))
    neg_list.append(sum(neg)/len(pos))
    obj_list.append(sum(obj)/len(pos))
    index=index+1
df['pos'] = pd.Series(pos_list, index=df.index)
df['neg'] = pd.Series(neg_list, index=df.index)
df['obj'] = pd.Series(obj_list, index=df.index)

# %%
pd.scatter_matrix(df,figsize=(20,20));

# %%
df.corr('spearman')
# Out:
#                  stars    useful     funny      cool   word_nr  word_nr_rel  \
# stars         1.000000 -0.054791 -0.075518  0.074301 -0.160511    -0.140504
# useful       -0.054791  1.000000  0.519254  0.639296  0.343307     0.343828
# funny        -0.075518  0.519254  1.000000  0.585289  0.256709     0.253370
# cool          0.074301  0.639296  0.585289  1.000000  0.270642     0.273910
# word_nr      -0.160511  0.343307  0.256709  0.270642  1.000000     0.989281
# word_nr_rel  -0.140504  0.343828  0.253370  0.273910  0.989281     1.000000
# ratio_noStop  0.184533 -0.073836 -0.073767 -0.038003 -0.325180    -0.198404
# pos           0.067592 -0.057403 -0.041965 -0.029579 -0.112896    -0.113666
# neg          -0.207160  0.058873  0.063449  0.020895  0.165447     0.157259
# obj          -0.032345  0.005585 -0.015358 -0.012997  0.060509     0.052213
#
#               ratio_noStop       pos       neg       obj
# stars             0.184533  0.067592 -0.207160 -0.032345
# ...

# %%
import os 
os.getcwd()
import sys
sys.path.append('/vagrant_data/YELP/ASI_yelp_nlp')
import posneg.posneg_wrapper as pnw
pnw.positive.contains("best")
# Out:
# True

# %%
import sklearn.ensemble as ens

# %%
RF= ens.RandomForestClassifier(oob_score=True,n_estimators=100)

# %%
y= df.useful
X= np.array( [ df.stars, df.funny, df.cool, df.word_nr, df.ratio_noStop] )

# %%
np.shape(X.transpose())
np.shape(y)
print np.min([ df.stars, df.funny, df.cool, df.word_nr, df.ratio_noStop])
# Out:
# 0.0

# %%
RF= RF.fit(X.transpose(),y)

# %%
RF.feature_importances_
# Out:
# array([ 0.05580789,  0.07119642,  0.16614422,  0.33410467,  0.3727468 ])

# %%
RF.oob_score_
# Out:
# 0.56153333333333333

# %%
pnw.positive.contains(df.word_list[0][1])
# Out:
# False
