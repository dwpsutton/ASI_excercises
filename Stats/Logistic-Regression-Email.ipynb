# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import pylab
import scipy.stats as stats
import statsmodels.api as sm
#mpl.style.available
#mpl.style.use('ggplot') 

# %matplotlib inline

# %% [markdown]
# ##Description
# These data represent incoming emails for the first three months of 2012 for an email account.
# ##Format
# A email (email_sent) data frame has 3921 (1252) observations on the following 21 variables.
#
# spam: Indicator for whether the email was spam.
#
# to_multiple: Indicator for whether the email was addressed to more than one recipient.
#
# from: Whether the message was listed as from anyone (this is usually set by default for regular outgoing email).
#
# cc: The number of people that were CCed.
#
# sent_email: Indicator for whether the sender had been sent an email in the last 30 days.
#
# time: Time at which email was sent.
#
# image: The number of images attached.
#
# attach: The number of attached files.
#
# dollar: The number of times a dollar sign or the word “dollar” appeared in the email.
#
# winner: Indicates whether “winner” appeared in the email.
#
# inherit: The number of times “inherit” (or an extension, such as “inheritance”) appeared in the email.
#
# viagra: The number of times “viagra” appeared in the email.
#
# password: The number of times “password” appeared in the email.
#
# num_char: The number of characters in the email, in thousands.
#
# line_breaks: The number of line breaks in the email (does not count text wrapping).
#
# format: Indicates whether the email was written using HTML (e.g. may have included bolding or active links).
#
# re_subj: Whether the subject started with “Re:”, “RE:”, “re:”, or “rE:”
#
# exclaim_subj: Whether there was an exclamation point in the subject.
#
# urgent_subj: Whether the word “urgent” was in the email subject.
#
# exclaim_mess: The number of exclamation points in the email message.
#
# number: Factor variable saying whether there was no number, a small number (under 1 million), or a big number.

# %% [markdown]
# Load email.txt on a data frame.

# %%
df= pd.read_table("email.txt")
df.head()
# Out:
#    spam  to_multiple  from  cc  sent_email                 time  image  \
# 0     0            0     1   0           0  2011-12-31 22:16:41      0
# 1     0            0     1   0           0  2011-12-31 23:03:59      0
# 2     0            0     1   0           0  2012-01-01 08:00:32      0
# 3     0            0     1   0           0  2012-01-01 01:09:49      0
# 4     0            0     1   0           0  2012-01-01 02:00:01      0
#
#    attach  dollar winner  ...    viagra  password  num_char  line_breaks  \
# 0       0       0     no  ...         0         0    11.370          202
# 1       0       0     no  ...         0         0    10.504          202
# 2       0       4     no  ...         0         0     7.773          192
# 3       0       0     no  ...         0         0    13.256          255
# 4       0       0     no  ...         0         2     1.231           29
#
#    format  re_subj  exclaim_subj  urgent_subj  exclaim_mess  number
# 0       1        0             0            0             0     big
# 1       1        0             0            0             1   small
# 2       1        0             0            0             6   small
# 3       1        0             0            0            48   small
# 4       0        0             0            0             1    none
#
# [5 rows x 21 columns]

# %% [markdown]
# Explore the data.

# %%
df.describe()
# Out:
#               spam  to_multiple         from           cc   sent_email  \
# count  3921.000000  3921.000000  3921.000000  3921.000000  3921.000000
# mean      0.093599     0.158123     0.999235     0.404489     0.277990
# std       0.291307     0.364903     0.027654     2.666424     0.448066
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     1.000000     0.000000     0.000000
# 50%       0.000000     0.000000     1.000000     0.000000     0.000000
# 75%       0.000000     0.000000     1.000000     0.000000     1.000000
# max       1.000000     1.000000     1.000000    68.000000     1.000000
#
#              image       attach       dollar      inherit       viagra  \
# count  3921.000000  3921.000000  3921.000000  3921.000000  3921.000000
# mean      0.048457     0.132874     1.467228     0.038001     0.002040
# std       0.450848     0.718518     5.022298     0.267899     0.127759
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max      20.000000    21.000000    64.000000     9.000000     8.000000
#
#           password     num_char  line_breaks       format      re_subj  \
# count  3921.000000  3921.000000  3921.000000  3921.000000  3921.000000
# mean      0.108136    10.706586   230.658505     0.695231     0.261413
# std       0.959931    14.645786   319.304959     0.460368     0.439460
# min       0.000000     0.001000     1.000000     0.000000     0.000000
# 25%       0.000000     1.459000    34.000000     0.000000     0.000000
# 50%       0.000000     5.856000   119.000000     1.000000     0.000000
# 75%       0.000000    14.084000   298.000000     1.000000     1.000000
# max      28.000000   190.087000  4022.000000     1.000000     1.000000
#
#        exclaim_subj  urgent_subj  exclaim_mess
# count   3921.000000  3921.000000   3921.000000
# mean       0.080337     0.001785      6.584290
# std        0.271848     0.042220     51.479871
# min        0.000000     0.000000      0.000000
# 25%        0.000000     0.000000      0.000000
# 50%        0.000000     0.000000      1.000000
# 75%        0.000000     0.000000      4.000000
# max        1.000000     1.000000   1236.000000

# %% [markdown]
# Explore the different types of variables  df.dtypes

# %%
df.dtypes
# Out:
# spam              int64
# to_multiple       int64
# from              int64
# cc                int64
# sent_email        int64
# time             object
# image             int64
# attach            int64
# dollar            int64
# winner           object
# inherit           int64
# viagra            int64
# password          int64
# num_char        float64
# line_breaks       int64
# format            int64
# re_subj           int64
# exclaim_subj      int64
# urgent_subj       int64
# exclaim_mess      int64
# number           object
# dtype: object

# %% [markdown]
# Change  cc, attach, dollar, winner, inherit and password to indicator factors.
#
# **Hint:** use df[var].map(lambda function)

# %%
df['cc']= df['cc'].map(lambda x: 1 if x >= 1 else 0)
df['attach']= df['attach'].map(lambda x: 1 if x >= 1 else 0)
df['dollar']= df['dollar'].map(lambda x: 1 if x >= 1 else 0)
df['winner']= df['winner'].map(lambda x: 1 if x >= 1 else 0)
df['inherit']= df['inherit'].map(lambda x: 1 if x >= 1 else 0)
df['password']= df['password'].map(lambda x: 1 if x >= 1 else 0)

df.head()
# Out:
#    spam  to_multiple  from  cc  sent_email                 time  image  \
# 0     0            0     1   0           0  2011-12-31 22:16:41      0
# 1     0            0     1   0           0  2011-12-31 23:03:59      0
# 2     0            0     1   0           0  2012-01-01 08:00:32      0
# 3     0            0     1   0           0  2012-01-01 01:09:49      0
# 4     0            0     1   0           0  2012-01-01 02:00:01      0
#
#    attach  dollar  winner   ...    viagra  password  num_char  line_breaks  \
# 0       0       0       1   ...         0         0    11.370          202
# 1       0       0       1   ...         0         0    10.504          202
# 2       0       1       1   ...         0         0     7.773          192
# 3       0       0       1   ...         0         0    13.256          255
# 4       0       0       1   ...         0         1     1.231           29
#
#    format  re_subj  exclaim_subj  urgent_subj  exclaim_mess  number
# 0       1        0             0            0             0     big
# 1       1        0             0            0             1   small
# 2       1        0             0            0             6   small
# 3       1        0             0            0            48   small
# 4       0        0             0            0             1    none
#
# [5 rows x 21 columns]

# %%
##Set X to be the explenatory variables to_multiple, cc, attach, dollar, winner, inherit, password, format,
##re_subj and exclaim_subj
#X= []
#X.append( df.to_multiple )
#X.append( df.cc )
#X.append( df.attach )
#X.append( df.dollar )
#X.append( df.winner )
#X.append( df.inherit )
#X.append( df.password )
#X.append( df.format )
#X.append( df.re_subj )
#X.append( df.exclaim_subj )
#X= numpy.array( X )

##Set y to be the respone variable spam
y= df.spam

##Set the logistic regression model
X= df[['to_multiple','cc','attach','dollar','winner','inherit','password','format','re_subj','exclaim_subj']]

#print np.shape(X)
logit = sm.Logit(y,X)

## fit the model
ess = logit.fit()
##See the summary statistics
ess.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.251521
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   spam   No. Observations:                 3921
# Model:                          Logit   Df Residuals:                     3911
# Method:                           MLE   Df Model:                            9
# Date:                Tue, 03 Mar 2015   Pseudo R-squ.:                  0.1907
# Time:                        15:21:59   Log-Likelihood:                -986.21
# converged:                       True   LL-Null:                       -1218.6
#                                         LLR p-value:                 2.006e-94
# ================================================================================
#                    coef    std err          z      P>|z|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# to_multiple     -2.8940      0.312     -9.275      0.000        -3.506    -2.282
# cc              -0.5253      0.305     -1.721      0.085        -1.123     0.073
# attach           0.9696      0.217      4.473      0.000         0.545     1.394
# dollar          -0.0157      0.157     -0.100      0.920        -0.324     0.292
# winner          -0.8024      0.095     -8.404      0.000        -0.990    -0.615
# inherit          0.2706      0.316      0.856      0.392        -0.349     0.890
# password        -1.3927      0.523     -2.664      0.008        -2.417    -0.368
# format          -1.5975      0.123    -12.977      0.000        -1.839    -1.356
# re_subj         -2.8457      0.369     -7.703      0.000        -3.570    -2.122
# exclaim_subj     0.2017      0.223      0.906      0.365        -0.235     0.638
# ================================================================================
# """

# %% [markdown]
# Apply the Backwards selection strategy to come up with the "best" model.

# %%
X= df[['to_multiple','cc','attach','winner','inherit','password','format','re_subj','exclaim_subj']]
logit2= sm.Logit(y, X)
ess2 = logit2.fit()
ess2.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.251522
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   spam   No. Observations:                 3921
# Model:                          Logit   Df Residuals:                     3912
# Method:                           MLE   Df Model:                            8
# Date:                Tue, 03 Mar 2015   Pseudo R-squ.:                  0.1907
# Time:                        15:26:15   Log-Likelihood:                -986.22
# converged:                       True   LL-Null:                       -1218.6
#                                         LLR p-value:                 2.558e-95
# ================================================================================
#                    coef    std err          z      P>|z|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# to_multiple     -2.8926      0.312     -9.278      0.000        -3.504    -2.282
# cc              -0.5244      0.305     -1.719      0.086        -1.122     0.074
# attach           0.9714      0.216      4.498      0.000         0.548     1.395
# winner          -0.8051      0.092     -8.795      0.000        -0.985    -0.626
# inherit          0.2604      0.299      0.870      0.384        -0.326     0.847
# password        -1.3913      0.523     -2.662      0.008        -2.416    -0.367
# format          -1.5978      0.123    -12.983      0.000        -1.839    -1.357
# re_subj         -2.8448      0.369     -7.703      0.000        -3.569    -2.121
# exclaim_subj     0.1957      0.215      0.912      0.362        -0.225     0.616
# ================================================================================
# """

# %%
X= df[['to_multiple','cc','attach','winner','password','format','re_subj','exclaim_subj']]
logit3= sm.Logit(y, X)
ess4 = logit3.fit()
ess4.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.251613
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   spam   No. Observations:                 3921
# Model:                          Logit   Df Residuals:                     3913
# Method:                           MLE   Df Model:                            7
# Date:                Tue, 03 Mar 2015   Pseudo R-squ.:                  0.1904
# Time:                        15:29:08   Log-Likelihood:                -986.58
# converged:                       True   LL-Null:                       -1218.6
#                                         LLR p-value:                 4.311e-96
# ================================================================================
#                    coef    std err          z      P>|z|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# to_multiple     -2.8924      0.312     -9.282      0.000        -3.503    -2.282
# cc              -0.5217      0.305     -1.712      0.087        -1.119     0.076
# attach           0.9628      0.215      4.470      0.000         0.541     1.385
# winner          -0.8015      0.091     -8.769      0.000        -0.981    -0.622
# password        -1.4007      0.522     -2.682      0.007        -2.424    -0.377
# format          -1.5807      0.121    -13.051      0.000        -1.818    -1.343
# re_subj         -2.8551      0.369     -7.736      0.000        -3.578    -2.132
# exclaim_subj     0.1843      0.214      0.862      0.389        -0.235     0.604
# ================================================================================
# """

# %%
X= df[['to_multiple','cc','attach','winner','password','format','re_subj']]
logit4= sm.Logit(y, X)
ess4 = logit4.fit()
ess4.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.251705
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   spam   No. Observations:                 3921
# Model:                          Logit   Df Residuals:                     3914
# Method:                           MLE   Df Model:                            6
# Date:                Tue, 03 Mar 2015   Pseudo R-squ.:                  0.1901
# Time:                        15:30:01   Log-Likelihood:                -986.94
# converged:                       True   LL-Null:                       -1218.6
#                                         LLR p-value:                 6.702e-97
# ===============================================================================
#                   coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# to_multiple    -2.8796      0.311     -9.254      0.000        -3.489    -2.270
# cc             -0.5132      0.304     -1.686      0.092        -1.110     0.084
# attach          0.9543      0.215      4.440      0.000         0.533     1.376
# winner         -0.7922      0.091     -8.735      0.000        -0.970    -0.614
# password       -1.3991      0.522     -2.679      0.007        -2.423    -0.375
# format         -1.5695      0.120    -13.054      0.000        -1.805    -1.334
# re_subj        -2.8663      0.369     -7.771      0.000        -3.589    -2.143
# ===============================================================================
# """

# %% [markdown]
# Write the final logistic regression model.

# %%
X= df[['to_multiple','attach','winner','password','format','re_subj']]
logit5= sm.Logit(y, X)
ess5 = logit5.fit()
ess5.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.252093
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   spam   No. Observations:                 3921
# Model:                          Logit   Df Residuals:                     3915
# Method:                           MLE   Df Model:                            5
# Date:                Tue, 03 Mar 2015   Pseudo R-squ.:                  0.1889
# Time:                        15:31:12   Log-Likelihood:                -988.46
# converged:                       True   LL-Null:                       -1218.6
#                                         LLR p-value:                 2.992e-97
# ===============================================================================
#                   coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# to_multiple    -2.8409      0.309     -9.204      0.000        -3.446    -2.236
# attach          0.8333      0.204      4.086      0.000         0.434     1.233
# winner         -0.8137      0.090     -9.049      0.000        -0.990    -0.637
# password       -1.3886      0.522     -2.660      0.008        -2.412    -0.365
# format         -1.5509      0.120    -12.962      0.000        -1.785    -1.316
# re_subj        -3.0130      0.362     -8.334      0.000        -3.722    -2.304
# ===============================================================================
# """

# %%
X= df[['to_multiple','attach','winner','format','re_subj']]
logit6= sm.Logit(y, X)
ess6 = logit6.fit()
ess6.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.253432
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   spam   No. Observations:                 3921
# Model:                          Logit   Df Residuals:                     3916
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 03 Mar 2015   Pseudo R-squ.:                  0.1845
# Time:                        15:32:22   Log-Likelihood:                -993.71
# converged:                       True   LL-Null:                       -1218.6
#                                         LLR p-value:                 4.888e-96
# ===============================================================================
#                   coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# to_multiple    -2.8181      0.309     -9.127      0.000        -3.423    -2.213
# attach          0.8662      0.204      4.256      0.000         0.467     1.265
# winner         -0.8547      0.089     -9.598      0.000        -1.029    -0.680
# format         -1.5428      0.119    -12.931      0.000        -1.777    -1.309
# re_subj        -2.9908      0.361     -8.276      0.000        -3.699    -2.282
# ===============================================================================
# """

# %% [markdown]
# How will the probability change is the are dollar signs in the email?
